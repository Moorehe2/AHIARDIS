# %% [markdown]
# <a href="https://colab.research.google.com/github/Moorehe2/AHIARDIS/blob/main/AMooreheadDepress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days (2).csv')

# %%
df
# Out:
#                                               Indicator  ... Quartile Range
# 0                       Symptoms of Depressive Disorder  ...            NaN
# 1                       Symptoms of Depressive Disorder  ...            NaN
# 2                       Symptoms of Depressive Disorder  ...            NaN
# 3                       Symptoms of Depressive Disorder  ...            NaN
# 4                       Symptoms of Depressive Disorder  ...            NaN
# ...                                                 ...  ...            ...
# 7132  Symptoms of Anxiety Disorder or Depressive Dis...  ...      21.6-26.2
# 7133  Symptoms of Anxiety Disorder or Depressive Dis...  ...      28.2-31.2
# 7134  Symptoms of Anxiety Disorder or Depressive Dis...  ...      31.3-37.5
# 7135  Symptoms of Anxiety Disorder or Depressive Dis...  ...      21.6-26.2
# 7136  Symptoms of Anxiety Disorder or Depressive Dis...  ...      26.3-28.1
#
# [7137 rows x 14 columns]

# %% [markdown]
# Potential Variable

# %%
df.columns
# Out:
# Index(['Indicator', 'Group', 'State', 'Subgroup', 'Phase', 'Time Period',
#        'Time Period Label', 'Time Period Start Date', 'Time Period End Date',
#        'Value', 'Low CI', 'High CI', 'Confidence Interval', 'Quartile Range'],
#       dtype='object')

# %% [markdown]
# Create National estimate with Group

# %%
df['Group'] == 'National Estimate'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7132    False
# 7133    False
# 7134    False
# 7135    False
# 7136    False
# Name: Group, Length: 7137, dtype: bool

# %% [markdown]
# Missing Data

# %%
df.isnull()
# Out:
#       Indicator  Group  State  ...  High CI  Confidence Interval  Quartile Range
# 0         False  False  False  ...    False                False            True
# 1         False  False  False  ...    False                False            True
# 2         False  False  False  ...    False                False            True
# 3         False  False  False  ...    False                False            True
# 4         False  False  False  ...    False                False            True
# ...         ...    ...    ...  ...      ...                  ...             ...
# 7132      False  False  False  ...    False                False           False
# 7133      False  False  False  ...    False                False           False
# 7134      False  False  False  ...    False                False           False
# 7135      False  False  False  ...    False                False           False
# 7136      False  False  False  ...    False                False           False
#
# ...

# %% [markdown]
# Missing Value

# %%
df.isna().sum()
# Out:
# Indicator                    0
# Group                        0
# State                        0
# Subgroup                     0
# Phase                        0
# Time Period                  0
# Time Period Label            0
# Time Period Start Date       0
# Time Period End Date         0
# Value                      171
# Low CI                     171
# High CI                    171
# Confidence Interval        171
# Quartile Range            2088
# dtype: int64

# %% [markdown]
# Transformation

# %%
df.dtypes
# Out:
# Indicator                  object
# Group                      object
# State                      object
# Subgroup                   object
# Phase                      object
# Time Period                 int64
# Time Period Label          object
# Time Period Start Date     object
# Time Period End Date       object
# Value                     float64
# Low CI                    float64
# High CI                   float64
# Confidence Interval        object
# Quartile Range             object
# dtype: object

# %% [markdown]
# Value Counts

# %%
df['Indicator'].value_counts()
# Out:
# Symptoms of Depressive Disorder                        2379
# Symptoms of Anxiety Disorder or Depressive Disorder    2379
# Symptoms of Anxiety Disorder                           2379
# Name: Indicator, dtype: int64

# %%
df['Group'].value_counts()
# Out:
# By State                      5049
# By Age                         756
# By Race/Hispanic ethnicity     540
# By Education                   432
# By Sex                         216
# National Estimate              108
# By Disability status            36
# Name: Group, dtype: int64

# %%
df['Subgroup'].value_counts().head(50)
# Out:
# 70 - 79 years                                   108
# 18 - 29 years                                   108
# 60 - 69 years                                   108
# United States                                   108
# Non-Hispanic Black, single race                 108
# 40 - 49 years                                   108
# Non-Hispanic, other races and multiple races    108
# 80 years and above                              108
# Female                                          108
# Non-Hispanic White, single race                 108
# 30 - 39 years                                   108
# Less than a high school diploma                 108
# High school diploma or GED                      108
# Non-Hispanic Asian, single race                 108
# 50 - 59 years                                   108
# Some college/Associate's degree                 108
# Male                                            108
# Bachelor's degree or higher                     108
# ...

# %%
df['Time Period Label'].value_counts().head(50)
# Out:
# Apr 23 - May 5       3
# July 2 - July 7      3
# Sep 2 - Sep 14       3
# Jan 6 - Jan 18       3
# Mar 17 - Mar 29      3
# May 26 - Jun 7       3
# Jan 20 - Feb 1       3
# Nov 11 - Nov 23      3
# May 21 - May 26      3
# May 14 - May 19      3
# Mar 3 - Mar 15       3
# Feb 3 - Feb 15       3
# June 11 - June 16    3
# July 9 - July 14     3
# June 4 - June 9      3
# Sep 16 - Sep 28      3
# Apr 14 - Apr 26      3
# July 22 - Aug 18     3
# Oct 28 - Nov 9       3
# Oct 14 - Oct 26      3
# May 7 - May 12       3
# June 25 - June 30    3
# Mar 30 - Apr 13      3
# Jun 9 - Jun 21       3
# May 12 - May 24      3
# Sep 30 - Oct 12      3
# May 28 - June 2      3
# Jun 23 - Jul 5       3
# Aug 19 - Aug 31      3
# Nov 25 - Dec 7       3
# Apr 28 - May 10      3
# Dec 9 - Dec 21       3
# June 18 - June 23    3
# Dec 22 - Jan 5       3
# July 16 - July 21    3
# Feb 17 - Mar 1       3
# Name: Time Period Label, dtype: int64

# %%
df['Low CI'].value_counts().head(50)
# Out:
# 35.2    3
# 30.0    2
# 24.7    2
# 33.1    2
# 40.7    2
# 28.9    2
# 25.8    2
# 28.2    2
# 30.9    2
# 29.5    2
# 27.5    2
# 23.9    2
# 28.8    2
# 25.0    2
# 35.5    2
# 27.0    2
# 25.2    2
# 20.2    2
# 24.5    1
# 36.2    1
# 35.0    1
# 23.7    1
# 37.2    1
# 40.6    1
# 23.0    1
# 22.7    1
# 26.1    1
# 29.3    1
# 30.1    1
# 38.7    1
# 35.6    1
# 32.0    1
# 30.5    1
# 31.4    1
# 37.0    1
# 24.8    1
# 30.2    1
# 21.0    1
# 26.5    1
# 24.0    1
# 31.0    1
# 41.5    1
# 35.3    1
# 40.2    1
# 36.1    1
# 21.3    1
# 38.3    1
# 30.7    1
# 36.8    1
# 34.4    1
# Name: Low CI, dtype: int64

# %%
df['High CI'].value_counts().head(50)
# Out:
# 36.8    4
# 36.9    4
# 42.2    3
# 33.2    2
# 25.0    2
# 34.7    2
# 28.7    2
# 37.7    2
# 32.1    2
# 30.8    2
# 21.6    2
# 26.3    2
# 36.5    2
# 38.5    2
# 38.2    2
# 25.2    2
# 28.9    2
# 27.2    1
# 31.7    1
# 41.2    1
# 32.2    1
# 37.1    1
# 26.2    1
# 24.3    1
# 29.3    1
# 26.6    1
# 31.1    1
# 29.9    1
# 26.0    1
# 35.5    1
# 37.0    1
# 32.5    1
# 32.0    1
# 39.6    1
# 30.5    1
# 29.0    1
# 28.6    1
# 28.1    1
# 40.0    1
# 27.0    1
# 22.4    1
# 33.1    1
# 26.9    1
# 25.7    1
# 25.6    1
# 35.1    1
# 31.2    1
# 28.2    1
# 33.6    1
# 31.4    1
# Name: High CI, dtype: int64

# %% [markdown]
# Central Tendency

# %%
df.describe()
# Out:
#        Time Period        Value       Low CI      High CI
# count  7137.000000  6966.000000  6966.000000  6966.000000
# mean     16.684741    30.657364    26.983233    34.574203
# std       9.747748     7.472522     7.456390     7.706644
# min       1.000000     6.400000     5.100000     7.900000
# 25%       8.000000    25.300000    21.500000    29.200000
# 50%      17.000000    30.500000    26.700000    34.400000
# 75%      25.000000    35.775000    31.900000    39.800000
# max      33.000000    64.300000    61.800000    66.800000

# %% [markdown]
# Create trend looking at National Estimate

# %%
df= df[df['Group']=='National Estimate']

# %%
df
# Out:
#                                               Indicator  ... Quartile Range
# 0                       Symptoms of Depressive Disorder  ...            NaN
# 70                         Symptoms of Anxiety Disorder  ...            NaN
# 140   Symptoms of Anxiety Disorder or Depressive Dis...  ...            NaN
# 210                     Symptoms of Depressive Disorder  ...            NaN
# 280                        Symptoms of Anxiety Disorder  ...            NaN
# ...                                                 ...  ...            ...
# 6777                       Symptoms of Anxiety Disorder  ...            NaN
# 6849  Symptoms of Anxiety Disorder or Depressive Dis...  ...            NaN
# 6921                    Symptoms of Depressive Disorder  ...            NaN
# 6993                       Symptoms of Anxiety Disorder  ...            NaN
# 7065  Symptoms of Anxiety Disorder or Depressive Dis...  ...            NaN
#
# [108 rows x 14 columns]

# %% [markdown]
# Visualation

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days (2).csv')

# %%
sns.barplot(data=df, x='High CI', y="Phase")

# %%
sns.boxplot(x= df['Time Period'])

# %%
sns.boxplot(x= df['Time Period'])

# %%
sns.boxplot(x=df['High CI'])

# %%
sns.boxplot(x=df['Low CI']

# %% [markdown]
# Joint Plot 2 variables

# %%
sns.barplot(data=df, x='Low CI', y="Phase")

# %%
import seaborn as sns
sns.jointplot(x= df['Low CI'], y = df['Phase'], kind = 'scatter')

# %%
sns.pairplot(df)

# %% [markdown]
# Regression Plot using low confidence and high confidence

# %%
sns.lmplot(x = 'High CI', y = 'Low CI', data = df, hue = 'Phase')

# %%
sns.barplot (data=df, x = 'Indicator', y= 'Value')

visual1 = sns.barplot(x=df['Indicator'], y=df['Value'])

visual1.set_xticklabels(visual1.get_xticklabels(), rotation=75)
# Out:
# [Text(0, 0, 'Symptoms of Depressive Disorder'),
#  Text(0, 0, 'Symptoms of Anxiety Disorder'),
#  Text(0, 0, 'Symptoms of Anxiety Disorder or Depressive Disorder')]

# %%
sns.barplot (data=df, x = 'Indicator', y= 'Low CI')

visual1 = sns.barplot(x=df['Indicator'], y=df['Low CI'])

visual1.set_xticklabels(visual1.get_xticklabels(), rotation=75)
# Out:
# [Text(0, 0, 'Symptoms of Depressive Disorder'),
#  Text(0, 0, 'Symptoms of Anxiety Disorder'),
#  Text(0, 0, 'Symptoms of Anxiety Disorder or Depressive Disorder')]

# %%
sns.barplot (data=df, x = 'Indicator', y= 'High CI')

visual1 = sns.barplot(x=df['Indicator'], y=df['High CI'])

visual1.set_xticklabels(visual1.get_xticklabels(), rotation=75)
# Out:
# [Text(0, 0, 'Symptoms of Depressive Disorder'),
#  Text(0, 0, 'Symptoms of Anxiety Disorder'),
#  Text(0, 0, 'Symptoms of Anxiety Disorder or Depressive Disorder')]
