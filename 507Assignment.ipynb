# %% [markdown]
# <a href="https://colab.research.google.com/github/Moorehe2/AHIARDIS/blob/main/507Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CMS 3 Hospital Datasets

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load Dataset

# %%
df_hospital = pd.read_csv("https://raw.githubusercontent.com/hantswilliams/AHI_DataSci_507/main/Deployment_Streamlit/hospital_info.csv")
df_inpatient = pd.read_csv("https://raw.githubusercontent.com/hantswilliams/AHI_DataSci_507/main/Deployment_Streamlit/inpatient_2015.csv")
df_outpatient = pd.read_csv("https://raw.githubusercontent.com/hantswilliams/AHI_DataSci_507/main/Deployment_Streamlit/outpatient_2015.csv")

# %% [markdown]
# This is the Hospital dataset sample

# %%
df_hospital.sample(5)
# Out:
#      provider_id  ...                      location
# 3542      341304  ...  POINT (-76.928183 35.989355)
# 5072      334048  ...   POINT (-73.952866 40.76987)
# 3135      161349  ...  POINT (-92.013385 42.173674)
# 791       100302  ...  POINT (-81.302658 28.242414)
# 5257      114035  ...   POINT (-84.39032 33.581378)
#
# [5 rows x 29 columns]

# %% [markdown]
# This is the outpatient data set

# %%
df_outpatient.sample(5)
# Out:
#       provider_id  ... average_total_payments
# 31568      460057  ...            1094.773974
# 28219      450177  ...            1096.677113
# 21447       80001  ...             126.881750
# 6287       500151  ...             684.455194
# 9226       340116  ...             990.542286
#
# [5 rows x 11 columns]

# %%
df_inpatient.sample(5)
# Out:
#         provider_id  ... average_medicare_payments
# 129237        50108  ...                  12968.07
# 180512       330126  ...                   5808.08
# 61511        440072  ...                   4390.92
# 102069       230156  ...                   3301.05
# 51579        150125  ...                   7164.97
#
# [5 rows x 12 columns]

# %% [markdown]
# Length of Database

# %%
print('outpatientlength:', len(df_outpatient))
print('hospitalength:', len(df_hospital))
print('inpatientlength:', len(df_inpatient))
_
# Out:
# outpatientlength: 32532
# hospitalength: 5314
# inpatientlength: 201876
#         provider_id  ... average_medicare_payments
# 129237        50108  ...                  12968.07
# 180512       330126  ...                   5808.08
# 61511        440072  ...                   4390.92
# 102069       230156  ...                   3301.05
# 51579        150125  ...                   7164.97
#
# [5 rows x 12 columns]

# %% [markdown]
# Cleaning datasets

# %%
# !pip install pyjanitor
# Out:
# ...
#      |████████████████████████████████| 135 kB 5.3 MB/s
# ...

# %% [markdown]
# Merge Dataset

# %%
df_hospital['provider_id'] = df_hospital['provider_id' ].astype(str)
df_outpatient['provider_id'] = df_outpatient['provider_id'].astype(str)

# %%
df_merged = df_outpatient.merge(df_hospital, how = 'left', left_on= 'provider_id', right_on = 'provider_id')

# %%
df_merged_clean = df_merged[df_merged['hospital_name'].notna()]

# %%
df_merged_clean.sample(5)

# %% [markdown]
# List of Stony Brook Hospital and Bronx Hospital Data Set. I will compare Stony Brook Hospital to Bronx Health System, St. Barnabas and Montefiorfe Medical Center.

# %%
df_SBrook = df_merged_clean[df_merged_clean['provider_city'] == 'Stony Brook']

# %%
df_Bronx = df_merged_clean[df_merged_clean['provider_city'] == 'Bronx']

# %%
Frames = [df_SBrook, df_Bronx]

# %%
Results= pd.concat(Frames)

# %%
Results
# Out:
#       provider_id  ...                              location
# 32321      330393  ...                                   NaN
# 32322      330393  ...                                   NaN
# 32323      330393  ...                                   NaN
# 32324      330393  ...                                   NaN
# 32325      330393  ...                                   NaN
# 32326      330393  ...                                   NaN
# 32327      330393  ...                                   NaN
# 32328      330393  ...                                   NaN
# 32329      330393  ...                                   NaN
# 32330      330393  ...                                   NaN
# 32331      330393  ...                                   NaN
# 32332      330393  ...                                   NaN
# 32333      330393  ...                                   NaN
# 1485       330009  ...  POINT (-73.903756 40.83175000000001)
# ...

# %% [markdown]
# What are the average total payments of Hospital clinic visits at Stony Brook Hospital vs. Bronx Hospitals? What is the average total payments for Level II Cardiac Imaging at Stony Brook vs. Bronx Hospitals?  What are the total payments for Level I Echocardiogram without contrast at Stony Brook vs. Bronx Hospitals. Does Stony Brook Hospital cost more or less for Level I-III Ultrasound than Bronx Hospitals. Is the total payments for Level I-IV cheaper at Stony Brook Hospital or Bronx Hospitals. Is the total payment for Level II Biopsy the same at Stony Brook and Bronx Hospitals?

# %%
Results.pivot(index ='provider_name', columns = 'apc', values = 'average_total_payments')
# Out:
# apc                                  0012 - Level I Debridement & Destruction  ...  0698 - Level II Eye Tests & Treatments
# provider_name                                                                  ...
# Bronx-Lebanon Hospital Center                                             NaN  ...                               92.393099
# Montefiore Medical Center                                                 NaN  ...                              115.012817
# St Barnabas Hospital                                                  91.3425  ...                               96.972857
# University Hospital ( Stony Brook )                                       NaN  ...                                     NaN
#
# [4 rows x 25 columns]

# %% [markdown]
# Stony Brook University Hospital inpatient DRG

# %%
df_hospital['provider_id'] = df_hospital['provider_id' ].astype(str)
df_inpatient['provider_id'] = df_inpatient['provider_id'].astype(str)

# %% [markdown]
# Merge Data

# %%
df1_merged = df_inpatient.merge(df_hospital, how = 'left', left_on= 'provider_id', right_on = 'provider_id')

# %%
df1_merged
# Out:
#        provider_id  ... location
# 0            30036  ...      NaN
# 1            30036  ...      NaN
# 2            30036  ...      NaN
# 3            30036  ...      NaN
# 4            30036  ...      NaN
# ...            ...  ...      ...
# 201871       50573  ...      NaN
# 201872       50573  ...      NaN
# 201873       50573  ...      NaN
# 201874       50573  ...      NaN
# 201875       50573  ...      NaN
#
# [201876 rows x 40 columns]

# %%
df1_merged_clean = df1_merged[df1_merged['hospital_name'].notna()]

# %%
df1_merged_clean
# Out:
#        provider_id  ...                              location
# 747         110023  ...           POINT (-84.92537 34.511878)
# 748         110023  ...           POINT (-84.92537 34.511878)
# 749         110023  ...           POINT (-84.92537 34.511878)
# 750         110023  ...           POINT (-84.92537 34.511878)
# 751         110023  ...           POINT (-84.92537 34.511878)
# ...            ...  ...                                   ...
# 201171      350070  ...  POINT (-96.828106 46.83250000000001)
# 201172      350070  ...  POINT (-96.828106 46.83250000000001)
# 201173      350070  ...  POINT (-96.828106 46.83250000000001)
# 201174      350070  ...  POINT (-96.828106 46.83250000000001)
# 201175      350070  ...  POINT (-96.828106 46.83250000000001)
#
# [166229 rows x 40 columns]

# %%
df1sb= df1_merged_clean[df1_merged_clean['hospital_name']=='SUNY/STONY BROOK UNIVERSITY HOSPITAL']

# %%
df1sb
# Out:
#        provider_id  ... location
# 200462      330393  ...      NaN
# 200463      330393  ...      NaN
# 200464      330393  ...      NaN
# 200465      330393  ...      NaN
# 200466      330393  ...      NaN
# ...            ...  ...      ...
# 200682      330393  ...      NaN
# 200683      330393  ...      NaN
# 200684      330393  ...      NaN
# 200685      330393  ...      NaN
# 200686      330393  ...      NaN
#
# [225 rows x 40 columns]

# %% [markdown]
# What are the maximum

# %%
df1M = df1_merged_clean[df1_merged_clean['hospital_name']=='MONTEFIORE MEDICAL CENTER']

# %%
df1M
# Out:
#       provider_id  ...                      location
# 9895       330059  ...  POINT (-73.879975 40.879777)
# 9896       330059  ...  POINT (-73.879975 40.879777)
# 9897       330059  ...  POINT (-73.879975 40.879777)
# 9898       330059  ...  POINT (-73.879975 40.879777)
# 9899       330059  ...  POINT (-73.879975 40.879777)
# ...           ...  ...                           ...
# 10122      330059  ...  POINT (-73.879975 40.879777)
# 10123      330059  ...  POINT (-73.879975 40.879777)
# 10124      330059  ...  POINT (-73.879975 40.879777)
# 10125      330059  ...  POINT (-73.879975 40.879777)
# 10126      330059  ...  POINT (-73.879975 40.879777)
#
# [232 rows x 40 columns]

# %% [markdown]
# COMPARISON OF DATASETS DRG Stony Brook Hospital and Montefiore Medical Center

# %%
Frames = [df1sb, df1M]

# %%
OResults = pd.concat(Frames)

# %%
OResults
# Out:
#        provider_id  ...                      location
# 200462      330393  ...                           NaN
# 200463      330393  ...                           NaN
# 200464      330393  ...                           NaN
# 200465      330393  ...                           NaN
# 200466      330393  ...                           NaN
# ...            ...  ...                           ...
# 10122       330059  ...  POINT (-73.879975 40.879777)
# 10123       330059  ...  POINT (-73.879975 40.879777)
# 10124       330059  ...  POINT (-73.879975 40.879777)
# 10125       330059  ...  POINT (-73.879975 40.879777)
# 10126       330059  ...  POINT (-73.879975 40.879777)
#
# [457 rows x 40 columns]

# %% [markdown]
# CREATE A PIVOT TABLE
#
# THE most expensive DRG at Stony Brook Hospital is an Operating Room  004- ECMO or Trach with MV, average covered charges 763781.83. Compared to Montefiore Medical Ceneter average covered chares of 771209.43.
# What is the cheapest DRG at Stony Brook Hospital is 149 - DYSEQUILIBRIUM at 29470.19. Montefiore average covered charges are 34022.82 for the same diagnosis.

# %%
OResults.pivot(index = 'hospital_name', columns = 'drg_definition', values = 'average_covered_charges')
# Out:
# drg_definition                        001 - HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SYSTEM W MCC  ...  982 - EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPAL DIAGNOSIS W CC
# hospital_name                                                                                         ...
# MONTEFIORE MEDICAL CENTER                                                     901745.46               ...                                          121652.79
# SUNY/STONY BROOK UNIVERSITY HOSPITAL                                                NaN               ...                                          120654.80
#
# [2 rows x 275 columns]
